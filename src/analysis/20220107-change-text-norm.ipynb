# %%
# %pwd
# Out:
# '/home/ruskirin/Documents/Projects/lin-que-dropping'

# %%
import os
import regex
import yaml
import matplotlib.pyplot as plt
from datetime import datetime
from pathlib import Path

# %%
path_win_down = Path('/home/../../mnt/c/Users/ruski/Downloads')
path_proj_dir = Path('/home/ruskirin/Documents/Projects/lin-que-dropping')

# %%
os.listdir(path_win_down)
# Out:
# ['1165-delaware-rent-202201.pdf',
#  'Boxcryptor_v2.49.1965_Setup.msi',
#  'desktop.ini',
#  'verbs-epistemic',
#  'verbs-stative',
#  'verbs-volitional']

# %%
with open(path_proj_dir/'main-conf.yml') as f:
    try:
        conf = yaml.safe_load(f)
    except Exception as e:
        print(e.args)

# %%
import numpy as np
import pandas as pd

# %%
name = lambda x: f'*{x}/*conj*/2021-11-07-extraction/*.xlsx'

# %%
files_e = [f for f in path_win_down.glob(name('epistemic'))]
files_v = [f for f in path_win_down.glob(name('volitional'))]
files_s = [f for f in path_win_down.glob(name('stative'))]

# %%
print(len(files_e), len(files_v), len(files_s))
# Out:
# 19 10 21

# %%
def save_readme(location, text, append=True):
    op = 'a+' if append else 'w'
    
    with open(location/'README.txt', op) as readme:
        readme.seek(0)
        
        if append and (len(readme.read(100)) > 0):
             text = '\n\n' + text
        
        readme.write(text)

# %%
def make_date_dir(
    path: Path,
    description,
    date: datetime = datetime.now().strftime(conf['date_format'])):
    """
    path: where to create directory
    date: (optional) specify datetime for folder name; defaults to time at runtime
    description: description of folder, included as README.txt
    
    return: created directory path
    """
    
    save_path = path/date
    
    try:
        save_path.mkdir(parents=True)
    except FileNotFoundError as fne:
        print(f'Path specified does not exist:\n{fne.args}')
    except Exception as e:
        print(e.args)
        
    save_readme(save_path, description, append=False)
    
    return save_path

# %%
def save_test_sample(name, location: Path, *files):
    """
    name: identifier for files (used in name-scheme of saved file)
    location: path to save directory
    
    return: randomized sample taken from all the tokens found in files
    """
    name_scheme = f'{name}-testing.csv'
    file_type = regex.search(r'\.(?<type>\w+)$', str(files[0]))['type']
    
    if file_type=='xlsx':
        data = pd.concat([pd.read_excel(f, dtype=conf['col_types']) for f in files], 
                         ignore_index=True)
    elif file_type=='csv':
        data = pd.concat([pd.read_csv(f, sep='~', dtype=conf['col_types']) for f in files], 
                         ignore_index=True)
    
    save_idx = np.random.choice(data.shape[0], int(data.shape[0]/20), replace=False)
    print(f'Creating testing sample ({name_scheme}) of length ({len(save_idx)})')
    
    sample = data.iloc[save_idx]
    sample.to_csv(location/name_scheme, sep='~', index=False)
    
    return sample

# %%
def save_csv(df, name, location):
    """
    General method for saving any dataframe/series
    
    name: filename to save as
    location: directory to save dataframe/series in
    """
    
    name_scheme = name+'.csv' if '.csv' not in name else name
    df.to_csv(location/name_scheme, sep='~', index=False)

# %%
do = False

if do:
    sd = '12/30: After the 12/6 meeting where decided on specific formatting of normd text '\
         '(lower case except for VOI). Will also be adding column for a hyperlink to the online '\
         'displaCy displayer'
    sp = make_date_dir(path_proj_dir/'saves'/'samples-for-testing', sd)
    
    test_sample_e = save_test_sample('epistemic', sp, *files_e)
    test_sample_v = save_test_sample('volitional', sp, *files_v)
    test_sample_s = save_test_sample('stative', sp, *files_s)

# %%
work_sample_v = pd.read_excel(files_v[np.random.randint(0, len(files_v)-1)])
work_sample_v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7058 entries, 0 to 7057
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   verbs               7058 non-null   object
#  1   text_orig           7058 non-null   object
#  2   dependencies        7058 non-null   object
#  3   has_ccomp           7058 non-null   bool
#  4   has_que             7058 non-null   bool
#  5   text_norm           7058 non-null   object
#  6   lemma_pos_stopword  7058 non-null   object
#  7   tweet_id            7058 non-null   float64
# dtypes: bool(2), float64(1), object(5)
# memory usage: 344.8+ KB

# %%
work_sample_v.head(2)
# Out:
#                           verbs  \
# 0  ['ver', 'esperar', 'sentir']
# 1         ['sentir', 'esperar']
#
#                                            text_orig  \
# 0  @epatriau @AdrianzenEduard @anibaltorresv Ya y...
# 1  @janyspring Ohh.. Lo siento mucho querida Jani...
#
#                                         dependencies  has_ccomp  has_que  \
# 0  Ya(ROOT) y(dep) ?() .() Superalo(ROOT) hijo(ob...       True     True
# 1  Ohh(ROOT) ..() Lo(obj) siento(ROOT) mucho(advm...       True     True
#
#                                            text_norm  \
# 0  Ya y?. Superalo hijo mio y ya no llores porque...
# 1  Ohh.. Lo siento mucho querida Janita, espero q...
#
#                                   lemma_pos_stopword      tweet_id
# 0  Ya(ya|ADV|True) y(y|CCONJ|False) Superalo(supe...  1.451168e+18
# 1  Ohh(ohh|INTJ|False) Lo(él|PRON|True) siento(se...  1.451166e+18

# %% [markdown]
# ### Check Tags
# See how exclusion of tags from spaCy processing might affect tagging

# %%
# Option to display more text from columns. Needed for quick analysis
pd.set_option('display.max_colwidth', None)

# %%
pat_tag = r'@\w+\b'

# %%
def get_tag_amt(tweet):
    return len(regex.findall(pat_tag, tweet))

# %% [markdown]
# #### Tags vs @'s

# %%
tag_amt = work_sample_v['text_orig'].apply(get_tag_amt).rename('tag_amt')
at_amt = work_sample_v['text_orig'].str.count('@').rename('at_amt')
print(f'Found {tag_amt.sum()} tags and {at_amt.sum()} @\'s')
# Out:
# Found 651 tags and 652 @'s

# %% [markdown]
# Reason for mismatch between '@' count and tag counts is due to the use of '@' in place of letters. Reasonable to assume that amount of tags should always be less than amount of '@'s

# %%
work_sample_v = pd.concat([work_sample_v, tag_amt, at_amt], axis=1)
work_sample_v.head(1)
# Out:
#                   verbs  \
# 0  ['sentir', 'querer']
#
#                                                                                                                                                                                                      text_orig  \
# 0  El 70% de la ciudadanía quiere que renuncie @LassoGuillermo por #PandoraPapers .\nEl 70 al 85 % de la ciudadanía siente miedo al salir por las últimas balaceras, Quito y Guayaquil respectivamente.\nHilo.
#
#                                                                                                                                                                                                                                                                                                                                                                                dependencies  \
# 0  El(det) 70%(nsubj) de(case) la(det) ciudadania(nmod) quiere(ROOT) que(mark) renuncie(ccomp) por(case) #() PandoraPapers(obl) .() El(det) 70(nsubj) al(case) 85(nmod) %() de(case) la(det) ciudadania(nmod) siente(ROOT) miedo(obj) al(mark) salir(acl) por(case) las(det) ultimas(amod) balaceras(obl) ,() Quito(appos) y(cc) Guayaquil(conj) respectivamente(advmod) .() Hilo(ROOT) .()
#
#    has_ccomp  has_que  \
# 0       True     True
#
#                                                                                                                                                                                    text_norm  \
# 0  El 70% de la ciudadania quiere que renuncie por #PandoraPapers . El 70 al 85 % de la ciudadania siente miedo al salir por las ultimas balaceras, Quito y Guayaquil respectivamente. Hilo.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   lemma_pos_stopword  \
# 0  El(el|DET|True) 70%(70%|SYM|False) de(de|ADP|True) la(el|DET|True) ciudadania(ciudadania|NOUN|False) quiere(querer|VERB|True) que(que|SCONJ|True) renuncie(renunciar|VERB|False) por(por|ADP|True) PandoraPapers(PandoraPapers|PROPN|False) El(el|DET|True) 70(70|NUM|False) al(al|ADP|True) 85(85|SYM|False) de(de|ADP|True) la(el|DET|True) ciudadania(ciudadania|NOUN|False) siente(sentir|VERB|False) miedo(miedo|NOUN|False) al(al|ADP|True) salir(salir|VERB|False) por(por|ADP|True) las(el|DET|True) ultimas(ultima|ADJ|False) balaceras(balacera|NOUN|False) Quito(Quito|PROPN|False) y(y|CCONJ|False) Guayaquil(Guayaquil|PROPN|False) respectivamente(respectivamente|ADV|False) Hilo(hilo|NOUN|False)
#
#        tweet_id  tag_amt  at_amt
# 0  1.451191e+18        1       1

# %%
e_tag_not_at = work_sample_v[tag_amt != at_amt].loc[:, ['tweet_id', 'text_orig', 'tag_amt', 'at_amt']]
print(f'Entries with mismatched tag and @ counts: {e_tag_not_at.shape[0]}')
display(e_tag_not_at)
# Out:
# Entries with mismatched tag and @ counts: 28
#            tweet_id  \
# 167    1.455164e+18
# 1024   1.453196e+18
# 1484   1.452978e+18
# 2105   1.451555e+18
# 2115   1.449008e+18
# 3812   1.454067e+18
# 5844   1.452738e+18
# 6841   1.452076e+18
# 7980   1.451303e+18
# 8941   1.450800e+18
# 10594  1.449806e+18
# 10626  1.449789e+18
# 10744  1.449707e+18
# 11001  1.449477e+18
# 12794  1.452650e+18
# 13047  1.450693e+18
# 13311  1.448404e+18
# 13447  1.448338e+18
# 13990  1.448006e+18
# 14146  1.447927e+18
# 14193  1.447908e+18
# 14995  1.447381e+18
# 15624  1.446993e+18
# 17376  1.456669e+18
# 17700  1.456442e+18
# 19102  1.455617e+18
# 19872  1.453411e+18
# 19974  1.451568e+18
#
#                                                                                                                                                                                                                                                                                                     text_orig  \
# 167                              Me pasan cosas subrralista... Famoso o gente conocid@... No voy a dar nombre cuento la historia.. ahora es famoso.. sale en TVE exactamente en. Los programas de Telecinco.. si hace nada ganar pasta por realities. Voy a mi tren, unas chicas q conozco le han pedido foto
# 1024                     @@SSC_CDMX Podrian apoyarnos,los administradores de la tintorería que tenemos al lado se encierran como hoy y ponen música sobrepasando los decibeles estipulados en el art 186BIS de la LeyAmbiental de Protección a la Tierra en la capital,ya se les ha pedido cordialmente y ...
# 1484                                                                                                                                                                                                                           @YoSoyDaniela3 \n\nListo.\nTerminamos tema Dani\nNo puedo des@ a quien lo pide
# 2105           @unPUTEmas Buenos días, @❤️! No me das tu nombre!\nTú dale lo que te pidan, no importa si el otro no sirve para nada. Tu siempre demuestra lo que vales. Si los demás son 💩💩💩 problema de ellos!\nTú, impecable y educado se las proporcionas. La vida después se va a encargar de demostrar 👇
# 2115                                                                                                                                      Le están pidiendo a Karina la Princesita que muestre la factura de lo que cobró en un evento jajaja. Si, ahí te muestro mis finanzas @ virgosinfotodeperfil12355689
# 3812                                                                                                                                                                                                                  Ayyy perdón @GabibazanO se me escapó ese @ te pido mildiiiis.... jajajajajajajajajajaja
# 5844               Hola a todos.Quiero prncp/aclarar  "@"a los q leen para q se haga notorio \n@angrytwittok @gomezaugier @patriciodm81 @josebrandan666 \nPOR FAVOR !!!!!NO SOY MEDICA, PERO: CUANTA GENTE MÁS TIENE Q MORIR?,Q NOS PASA Q NO REACCIONAMOS Y PEDIMOS LO Q X DERECHO NOS CORRESPONDE???(sigue)
# 6841                                                                                                                                                                                                                                @Diego_Molano Extradición pedimos #nomasimpunidad @\n@IvanDuque #Colombia
# 7980                                                                                                                                                     @esmigoz @DesvariosdeMono @Tonicanto1 ¿Cuanto la renta te sale a devolver, decides que hacienda se lo queda o eludes y pides la devolución? Listill@
# 8941                          Increíbles las mentiras que acaba de decir el de “opinión” en @NTelevisa_com Mentira 1 “nadie está pidiendo la revocación de mandato” Fr3n@ ya está recabando firmas y se reunió con el @INEMexico 2. “Los que promueven la revocación, en si piden ratificación” FALSO pedimos
# 10594                   Tengo años regalando cobijas a personas en situación de calle esté año a sido difícil y les comenté a mis ex compañeros que me apoyarán ( primera vez que pido apoyo para eso ) ningun@ pudo jajaja quedé ,🤡 y eso que todos dicen que son pudientes nunca más vuelvo a pedir apoyo .
# 10626                          Explícame, si vos en el termo tenias agua y vas a tomar mate. Porq tiras el agua. Nooooo hij@ la pones en la pava y la calentas otra vez, es agua el agua no queda fea si la calentas. Te pido por el amor de dios q no tires el agua del termo en mi presencia. Comprendido(?
# 10744                                                    Alguén nos pode explicar como funciona a hospedaría, construída cos cartos do herario público e que rexentan as .Máis Bernardas, co inconvinte de que cando se les pide información, segundo quen sexa @ demandante, resposta dun modo ou doutro. 😔😔
# 11001                      Puerta de súper. Hombre muy joven (me atrevo a decir que tendría la mitad de mi edad) porte físico más que saludable, sin ninguna discapacidad aparente. Me dice "señora, me ayuda con algo?"... \nNingun@ pide trabajo, todos quieren ayuda, que proviene del trabajo de otr@s! 😡
# 12794                                                                                                                                         El mayor problema del usuario es que llama para pedir ayuda, no te escucha y encima pone en duda todo lo que le dices. #FelizLunes Bienvenid@ a mi lista negra.
# 13047                                                                                          Cuando te sientas harto, cansado y no contento con tu vida, recuerda que alguien en este preciso momento está pidiendo con todas sus fuerzas lo que tú tienes. \n\nNo te quejes y vive la vida.\n😘\n¡Ridícul@!
# 13311                                                                                                                                                                                           He pedido 3 pares de lentillas y saben cuántos me han llegado??? Exacto cero @ aduanas me cago en tus muertos
# 13447  @MarcoRubioCuba SI EL CARÁCTER DEL SOCIALISMO EN CUBA ES IRREVOCABLE,ENTONCES HAY Q@ DARLE AL @PartidoPCC Y SU CONSTITUCIÓN UNA CARGA AL MACHETE,HAY SOLUCIÓN PACÍFICA ??INTERVENCION MILITAR HUMANITARIA P CUBA ES LO QUE PEDIMOS LOS CUBANOS @USEmbCuba @Hola_Otaola @MaElviraSalazar @RosaMariaPaya
# 13990                                                                                                                                                                                                     @machupoume @Atreyus74 @PabloIglesias Ahora pides también dinero???? Pues no eres list@, jajajajaja
# 14146                                                                                                   Va a quedar la caga por que ahora todos los niños quieren ir ya que están vacunados con la primera dosis y están las mamás que pidieron autorización pa mandar todos los días él/la niñ@ al colegio 😅
# 14193                                                                                                                                                                   @MariaVisionTV @ le pido a la virgen de Zapopan interseda por todos para que sigamos adelante con esta pandemia y crisis económica 🙏🙏
# 14995                                                                                                               Vamosna a hacer tendencia ya para qué se vaya berizzo de una vez y qué asuma costas o un paraguayo, ovalemao!! Hace 1 año qué pedimos ya es hora que se vaya a la pooot@@@@@@ si quiere !
# 15624                                                                                                                                                                                                                                                @jacoblablaa ¿Y dónde se pide esa @? Es para una tarea 🤭
# 17376                                                     #DecisiónVerdeYa \nTenemos un momento único que estamos desaprovechando, desde febrero pedimos que se definiera el rumbo del candidat@ verde y no se ha decidido nada. Pedimos a los co presidentes que se pronuncien, pedimos una #DecisiónVerdeYa
# 17700                                                                                                                    Reconocer un error no es humillarse, es crecer como persona... Por favor no te olvides de los demás! Quien pide por los otros aboga por si mism@... #HagamosQueSuceda! Buena Noche 🌹
# 19102                Si vas a estudiar para ser docente no es solo enseñar al alumn@ la materia, si te pide ayuda con algo fuera de la materia, ayudal@ no podes callarte y ser cómplice de algo que le está sucediendo. En éste caso alumnos que quieren secuestrarlas violarlas y torturarlas.ESO ES DELITO
# 19872                Traen su mascota enferma hace mucho más tiempo del que nos dicen (si, nos damos cuenta de todo) y esperan un milagro d part nuestra. Muchas veces x mucho tratamiento es imposible salvarl@. Cuál es el resultado final?: el enojo/agresión hacia los profesionales. Pedimos respeto! 🙏🏼
# 19974                  Por favor pueden ir despidiendo el o la que cuenta los tweest ,por favor se debió marear que está restando en vez de sumar ,no pasa nada lo quitan y ponen un@ nuevoo la maquna se estropreó ,no creo que sea mucho pedir al señor twuiter ,que ponga atencion en ésto .\n#KeremBürsin
#
#        tag_amt  at_amt
# 167          0       1
# 1024         1       2
# 1484         1       2
# 2105         1       2
# 2115         0       1
# 3812         1       2
# 5844         4       5
# 6841         2       3
# 7980         3       4
# 8941         2       3
# 10594        0       1
# 10626        0       1
# 10744        0       1
# 11001        1       2
# 12794        0       1
# 13047        0       1
# 13311        0       1
# 13447        6       7
# 13990        3       4
# 14146        0       1
# 14193        1       2
# 14995        0       6
# 15624        1       2
# 17376        0       1
# 17700        0       1
# 19102        0       2
# 19872        0       1
# 19974        0       1

# %%
# Saving above sample as example 

p = path_proj_dir/'saves'/'examples'
n = 'useof-at-vs-tags'
desc = f'{n}: sample entries with mismatched @ and tag (@xxxx) counts'

save_readme(p, desc)
save_csv(e_tag_not_at, n, p)

# %% [markdown]
# #### Checking presence of tags

# %%
distrib = []

for f in files_v:
    data = pd.read_excel(f)
    
    tag_amt = data['text_orig'].apply(get_tag_amt).rename('tag_amt')
    has_tags = tag_amt > 0
    
    ratio = has_tags.sum()/tag_amt.shape[0]
    
    distrib.append(ratio)

# %%
avg = sum(distrib)/len(distrib)

plt.bar(list(range(len(distrib))), distrib)
plt.hlines(avg, -1, len(distrib)+1, colors=['g'], label=f'average ({avg})')
plt.legend()
plt.show()

# %% [markdown]
# Safe to say that tags are frequently used and their exclusion might have a large impact on the POS tagging

# %% [markdown]
# ### Changing Normalized Content

# %%
import spacy
from spacy import displacy
# spacy.require_gpu()

nlp = spacy.load('es_dep_news_trf', disable=conf['spacy']['pipe_disable'])
# Out:
# /home/ruskirin/miniconda3/envs/nlp/lib/python3.9/site-packages/spacy/util.py:1636: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %%
tag_amt = work_sample_v['text_orig'].apply(get_tag_amt)
has_tags = work_sample_v[tag_amt > 0]

rand_idx = np.random.choice(has_tags.shape[0], 100, replace=False)
rand_idx = np.sort(rand_idx)

tagged_sample = has_tags.iloc[rand_idx]
tagged_sample.head(3)
# Out:
#                                  verbs  \
# 79                         ['esperar']
# 81               ['esperar', 'querer']
# 167  ['esperar', 'decir', 'responder']
#
#                                              text_orig  \
# 79   @tere_marinovic Esperemos que el sentido común...
# 81   @CarlosChaviraR @ElProdigio182 @lopezobrador_ ...
# 167  @VTRChile @VTRsoporte q pasa con Uds???? No ha...
#
#                                           dependencies  has_ccomp  has_que  \
# 79   Esperemos(nmod) que(mark) el(det) sentido(ROOT...      False     True
# 81   O(cc) sea(fixed) que(mark) lo(obj) apoyas(ROOT...       True     True
# 167  q(nsubj) pasa(ROOT) con(case) Uds(obl) ?() ?()...       True     True
#
#                                              text_norm  \
# 79                Esperemos que el sentido comun prime
# 81   O sea que lo apoyas para que tu empresa sea de...
# 167  q pasa con Uds???? No hay forma de comunicarme...
#
#                                     lemma_pos_stopword      tweet_id
# 79   Esperemos(esperar|VERB|False) que(que|SCONJ|Tr...  1.449899e+18
# 81   O(o|CCONJ|False) sea(sea|NOUN|True) que(que|SC...  1.449871e+18
# 167  q(q|PRON|False) pasa(pasar|VERB|False) con(con...  1.453832e+18

# %%
docs = tagged_sample['text_orig'].apply(nlp)

# %% [markdown]
# #### CHANGE:
# Will be combining consecutive tags into one generic to prevent spacy interpreting each tag as different POS

# %%
img = displacy.render(docs, style='dep', jupyter=False)

# %%
desc = 'combine-tags: (SVG, CSV) displacy\'s dependency trees for a random sample of tweets'

p_i = path_proj_dir/'saves'/'examples'/'combine-tags.svg'
p_d = path_proj_dir/'saves'/'examples'

# save_readme(path_proj_dir/'saves'/'examples', desc, append=True)
p_i.open('w', encoding='utf-8').write(img)
save_csv(tweets, 'combine-tags', p_d)

# %%
displacy.render(docs, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="cf4f6b1d60ee4c26aea3646312f500a9-0" class="displacy" width="1275" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">@tere_marinovic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Esperemos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">el</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">sentido</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">común</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">prime</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf4f6b1d60ee4c26aea3646312f500a9-0-0" stroke-width="2px" d="M420,352.0 C420,89.5 1095.0,89.5 1095.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf4f6b1d60ee4c26aea3646312f500a9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf4f6b1d60ee4c26aea3646312f500a9-0-1" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf4f6b1d60ee4c26aea3646312f500a9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf4f6b1d60ee4c26aea3646312f500a9-0-2" stroke-width="2px" d="M770,352.0 C770,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf4f6b1d60ee4c26aea3646312f500a9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf4f6b1d60ee4c26aea3646312f500a9-0-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf4f6b1d60ee4c26aea3646312f500a9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,354.0 L918.0,342.0 902.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf4f6b1d60ee4c26aea3646312f500a9-0-4" stroke-width="2px" d="M245,352.0 C245,2.0 1100.0,2.0 1100.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf4f6b1d60ee4c26aea3646312f500a9-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,354.0 L1108.0,342.0 1092.0,342.0" fill="currentColor"/>
# </g>
# </svg>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="cf4f6b1d60ee4c26aea3646312f500a9-1" class="displacy" width="10375" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">@CarlosChaviraR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">@ElProdigio182</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">@lopezobrador_</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">sea</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">lo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">apoyas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">para</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">tu</tspan>
#     <tspan class="displacy-tag" dy="2em" fi

# %% [markdown]
# #### Replacing Consecutive Tags w/ One

# %%
pat_cons_tags = r''

# %% [markdown]
# ### Adding Column w/ Link to Displacy Dependency Tree

# %%
pd.reset_option('display.max_colwidth')

# %%
work_sample_v.head(1)
# Out:
#                                    verbs  \
# 0  ['sentir', 'mandar', 'pensar', 'ver']
#
#                                            text_orig  \
# 0  Hoy amanecí con ganas de mandar todo a la chin...
#
#                                         dependencies  has_ccomp  has_que  \
# 0  Hoy(advmod) amaneci(ROOT) con(case) ganas(obl)...       True     True
#
#                                            text_norm  \
# 0  Hoy amaneci con ganas de mandar todo a la chin...
#
#                                   lemma_pos_stopword      tweet_id
# 0  Hoy(hoy|ADV|True) amaneci(amaneci|VERB|False) ...  1.451164e+18
